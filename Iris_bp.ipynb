# %%
#импортируем библиотеки
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap
from sklearn.neighbors import KNeighborsClassifier

# %%
#загружаем датасет
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
#делим на трэйн и тест
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
#строим график кнн классификация
plt.scatter(X[:,0], X[:,1],c=y, marker= 'o', s=50, cmap=cmap_bold)
plt.show()


knn = KNeighborsClassifier(n_neighbors=5, weights='distance') 
knn.fit(X_train, y_train)


predictions = knn.predict(X_test)
print('KNN ', knn)
print('Accuracy of KNN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of KNN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# KNN  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='distance')
# Accuracy of KNN classifier on training set: 1.00
# Accuracy of KNN classifier on test set: 0.97

# %%
#knn классификация с исходными датами
knn = KNeighborsClassifier(n_neighbors=5, weights='distance') 
knn.fit(X, y)
predictions = knn.predict(X)
print(metrics.accuracy_score(y, predictions))
# Out:
# 1.0

# %%
#выбираем подходящий n_neighbors
k_range = range(1, 30)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    predictions1 = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, predictions1))


plt.plot(k_range, scores)
plt.show()

# %%
#точность модели
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, predictions1))
print(classification_report(y_test, predictions1))
# Out:
# [[13  0  0]
#  [ 0 13  3]
#  [ 0  1  8]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.93      0.81      0.87        16
#            2       0.73      0.89      0.80         9
#
#     accuracy                           0.89        38
#    macro avg       0.89      0.90      0.89        38
# weighted avg       0.91      0.89      0.90        38
